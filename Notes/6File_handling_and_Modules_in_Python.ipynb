# %% [markdown]
# <font size = "5"> File Handling and I/O

# %% [markdown]
# When we are working in Python we dont have to import any third party library to open, read and write files. Python has its won native support to do these things. Let's see how it is done.

# %%
#Check the current directory
# %pwd
# Out:
# 'C:\\Users\\ranja\\OneDrive\\Desktop\\Data Science\\class2'

# %% [markdown]
# Python provides basic functions and methods necessary to manipulate files by default. You can do most of the file manipulation using a file object

# %% [markdown]
# The <b><i>OPEN </b></i> Function <br>
# Before you can read or write a file, you have to open it using Python's built-in <u> open() </u> function. This function creates a file object, which would be utilized to call other support methods associated with it <br><br>
# The open function takes two arguments, the name of the file and and the mode
# for which we would like to open the file.
#
# By default, when only the filename is passed, the open function opens the file
# in read mode.

# %% [markdown]
# Syntax <br>
# file object = open(file_name , access_mode)

# %%
# Importing a file to Python
file = open('sample.txt', 'r')
# Here we can directly open the file as our file is in same location as our Python code
print(file)

file.close()

print(file.closed)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>
# True

# %% [markdown]
# As you can see in the above example we have passed two arguments, one is file name and the other is the mode. 'r' is the mode here and as you can guess it stands for reading the file. 'r' is also the default mode. The other modes are -
#
# r = Reading the file
# w = Writing the file
# a = Append the file
# r+ = Both reading and writing file

# %%
print(file.name)# Print the name of the file
print(file.mode)# Print the current mode of the file
file.close() # After you use the file, you need to close the file
# Out:
# sample.txt
# r

# %% [markdown]
# Remember in the above syntax we always need to close the file manually whenever we call the open function as there is a limitation of operating system on how many files can an application open at once. So to avoid these confusion it is always recommended to open a file using context manager.

# %%
file = open('sample.txt', 'r')
# file_content = file.read()
# file_content = file.readlines()
# file_content = file.readline()
# print(file_content, end = '')

# file_content = file.readline()
# print(file_content, end = '')

for line in file:
    print(line)# We can use a iterator to iterate over the new lines

file.close()
# Out:
# This is a sample text file.
# This line is your second line.
# Now we are in the third line.

# %% [markdown]
# <b>Assignment - Create a file named 'sample.txt' in your system with 6 lines and read the first 100 characters from the file.
#
# Hint - Use read(100)

# %% [markdown]
# <font size = '4'> Context Manager

# %% [markdown]
# Context managers allow you to allocate and release resources precisely when you want to. The most widely used example of context managers is the 'with' statement. Suppose you have two related operations which you’d like to execute as a pair(in our example it is open and close), with a block of code in between. Context managers allow you to do specifically that. For example, the above code can be written as -

# %%
# See the position of the variable name, it is in the right instead of left
with open('sample.txt','r') as f:
    print(f.name)
    f_content = f.read(36)
    print(f_content)
    print(f.tell())
    
# Now we dont have to close the file manually as before, context manager will take care of it for us
print(f.closed)

# f.read()
# Out:
# sample.txt
# This is a sample text file.
# This li
# 37
# True

# %% [markdown]
# Reading file in binary mode

# %%
with open('sample.txt','rb') as file:
    for line in file:
        print(line)
# Out:
# b'This is a sample file\n'
# b'This file is located in my working directory'

# %%
# Now lets see some basic operation that we can do with our file
with open('sample.txt', 'r') as f:
    f_content = f.read()
    print(f_content)
# Out:
# This is a sample text file.
#
# This line is your second line.
#
# Now we are in the third line.

# %% [markdown]
# Read function will load all the text inside the file. Lets say we have a very large file and we don't want to print out all the lines at once. In this case we can use 'readline'.

# %%
# with open('sample.txt', 'r') as f:
#     cnt = 0
#     for line in f:
#         if cnt < 1:
#             print(line, end='')
#             cnt += 1
            
with open('sample.txt', 'r') as f:
    f_content = f.readline()
    print(f_content)
#     f_content = f.readline()
#     print(f_content)
    # As you can see it printout only the first line
    # If we will call the readline() function again then we can print the next line
# Out:
# This is a sample text file.

# %% [markdown]
# If we need to print out the first 30 characters of the text file then we can do that by calling read(30). For ex:

# %%
with open('sample.txt', 'r') as f:
    f_content = f.read(20)
    print(f_content, end = '$$')
    f_content = f.read(20)
    print(f_content, end = '$$')
#     f.seek(0) # Reset the index position to 0 
#     f_content = f.read(20)
#     print(f_content, end = '$$')
# Out:
# This is a sample tex$$t file.
# This line i$$is a sample text fil$$

# %% [markdown]
# So, how this process is working behind the scene? Whenever we open a file, our python interpreter create a file object which points the beginning of the text file. If we are calling the function readline(), then the file object will go and search for the line break in the file and point the starting of new line.
#
# tell() function can help us find the current location of file object and we can reset the file object location to beginning by  calling seek(0) function.

# %% [markdown]
# <b>  Read () </b><br>
# The read functions contains different methods, read(),readline() and readlines()
#
# read()		#return one big string
#
# readline	#return one line at a time
#
# readlines	#returns a list of lines

# %% [markdown]
# <b>  Write () </b><br>
#
# This method writes a sequence of strings to the file.
#
# write ()	#Used to write a fixed sequence of characters to a file
#
# writelines()	#writelines can write a list of strings.

# %% [markdown]
# <b>  Append() </b><br>
#
# The append function is used to append to the file instead of overwriting it.
#
# To append to an existing file, simply open the file in append mode ("a"):

# %% [markdown]
# <b>  Close() </b><br>
#
# When you’re done with a file, use close() to close it and free up any system
# resources taken up by the open file

# %% [markdown]
# Let's see some examples of file writing.

# %%
#To write to a file, use:
# Remember if the file is not created then in write mode it will create the file for you
# And if the file is already created then it will overwrite the current file
with open("sample3.txt","w") as fh:
    fh.write("Hello World, I am learning file handling in Python today")

# %%
#To write to a file, use:
with open("sample4.txt", "w") as wf:
    lines_of_text = ["a line of text\n", "another line of text\n", "a third line"]
    wf.writelines(lines_of_text)

# %% [markdown]
# <b>Assignment - Open an existing file from your computer and copy all the contents to a new file at a time.

# %%
with open('sample.txt', 'r') as rf:
    with open('copy_sample.txt', 'w') as wf:
        for lines in rf:
            wf.write(lines)

# %%
#To append to file, use:
with open("sample.txt", "a") as rf:
    rf.write("Hello World again")

# %%
#How to copy a image file to a new image file
#Keep a cat image inside your folder with name 'cat1.jpg' to make this work
with open('cat1.jpg', 'rb') as rf:
    with open('cat1_copy.jpg', 'wb') as wf:
        for lines in rf:
            wf.write(lines)

# %%
# with open('canada_company_sales_data.xlsx') as f:
#     print(f.readlines())
import pandas as pd
# df = pd.read_csv('sample_submission.csv')
# df

# Do this first to make it work - pip install xlrd
import xlrd
df = pd.read_excel('canada_company_sales_data.xlsx')
df
# Out:
#       Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          928 2011-03-01            Low              26    390.2000
# 1        32323 2010-07-23           High              38    259.7175
# 2        48353 2012-12-15  Not Specified              18     71.2200
# 3        10144 2011-01-02       Critical               1    192.4900
# 4        26756 2012-05-10         Medium              25    767.2600
# 5        18144 2011-06-07       Critical              48    207.0800
# 6        10369 2011-11-09            Low              23    683.6800
# 7        22912 2010-10-16            Low              33  10168.2300
# 8        51008 2011-08-20           High              20    269.6600
# 9        18279 2009-02-26         Medium              20  10281.7900
# 10       21635 2009-12-02            Low               2     65.3100
# 11       22656 2010-12-22  Not Specified              10    309.3000
# 12       54882 2011-02-06       Critical               2     86.9200
# 13       25031 2009-08-23           High              24   4636.6200
# 14       59684 2010-12-29         Medium               3     14.4600
# 15         775 2011-03-17       Critical               8     31.8700
# 16       29376 2012-08-11       Critical              20   2850.3100
# 17       37505 2011-06-03            Low              42    384.4100
# 18       57382 2009-03-23         Medium              45    452.9300
# 19        7136 2009-03-22           High               9     47.2800
# 20       57542 2009-08-22           High              23   1256.2900
# 21       53024 2012-05-12  Not Specified              46   2255.1945
# 22       59202 2012-09-08         Medium               7     83.8100
# 23       12067 2010-02-04       Critical               7    407.1160
# 24       45670 2012-08-07            Low               2     20.1600
# 25       31939 2011-06-25           High              13   1506.8375
# 26       42243 2012-03-11         Medium              19    145.2600
# 27       13536 2009-08-18         Medium              23    123.1500
# 28       32996 2010-12-17       Critical               2    116.3140
# 29       16133 2009-09-25       Critical               1     27.9600
# ...        ...        ...            ...             ...         ...
# 8369      8292 2010-02-01  Not Specified              18    299.8700
# 8370     13923 2012-07-08           High              49   1220.2300
# 8371     39399 2012-12-17         Medium              28    303.9700
# 8372     16547 2009-02-18  Not Specified              30  10554.6300
# 8373     46726 2012-07-05  Not Specified              46    325.9700
# 8374     32966 2012-01-26            Low              43     74.1700
# 8375     42022 2009-09-24         Medium              11     43.2500
# 8376     26306 2012-10-30            Low              15   2567.6400
# 8377     34530 2010-08-30            Low              38    612.4900
# 8378     22020 2010-05-17       Critical              37    498.2800
# 8379      3040 2010-04-11         Medium              13     98.3900
# 8380     25092 2010-12-01           High               6    141.2700
# 8381     52071 2011-11-27  Not Specified               1     12.7400
# 8382     12930 2011-11-24           High              49   1147.6400
# 8383     28582 2012-01-22  Not Specified              45    377.3100
# 8384     52389 2011-10-21       Critical              31    655.3300
# 8385     44519 2010-05-19           High              34    365.7700
# 8386     11425 2011-06-22       Critical              29    482.9100
# 8387     23906 2010-09-20       Critical              37    321.0200
# 8388      4359 2010-03-02       Critical              21    215.7600
# 8389     51971 2011-10-03  Not Specified              39   1326.0400
# 8390     35686 2010-10-02           High              48    313.5200
# 8391      5472 2010-04-10            Low              12   1098.1490
# 8392     27841 2012-09-16           High              33     67.8500
# 8393     59204 2012-02-29         Medium              25    151.7500
# 8394     21573 2012-04-25       Critical              31     96.2300
# 8395     43111 2011-09-12           High              27   4722.8300
# 8396      6850 2010-02-11           High               8     81.5600
# 8397     57440 2010-07-23            Low              12   1171.2320
# 8398      2438 2010-07-14           High              20    278.6800
#
#            Ship Mode  Shipping Cost               Province Customer Segment  \
# 0        Express Air           7.40       British Columbia         Consumer
# 1        Regular Air           5.03                Ontario   Small Business
# 2        Regular Air           0.70       British Columbia        Corporate
# 3     Delivery Truck          30.00       British Columbia        Corporate
# 4        Regular Air           4.00       British Columbia      Home Office
# 5        Regular Air           5.17  Northwest Territories        Corporate
# 6        Regular Air           8.99       British Columbia      Home Office
# 7        Express Air          19.99                  Yukon        Corporate
# 8        Regular Air           4.59                 Quebec         Consumer
# 9        Regular Air          24.49                Alberta         Consumer
# 10       Regular Air          12.98            Saskachewan         Consumer
# 11       Express Air           6.50   Prince Edward Island        Corporate
# 12       Regular Air          13.89               Manitoba         Consumer
# 13       Regular Air          69.00       British Columbia         Consumer
# 14       Regular Air           2.26               Manitoba        Corporate
# 15       Regular Air           1.20            Nova Scotia   Small Business
# 16       Regular Air           7.07          New Brunswick         Consumer
# 17       Regular Air           5.76       British Columbia      Home Office
# 18       Express Air           5.76                Ontario         Consumer
# 19       Regular Air           0.50       British Columbia      Home Office
# 20       Regular Air           6.79                Ontario        Corporate
# 21       Regular Air           5.00                Ontario        Corporate
# 22       Regular Air           0.50   Prince Edward Island         Consumer
# 23       Regular Air          19.99            Saskachewan   Small Business
# 24       Regular Air           7.86                 Quebec        Corporate
# 25       Regular Air           4.20                  Yukon   Small Business
# 26       Regular Air           5.96               Manitoba   Small Business
# 27       Regular Air           2.04                  Yukon      Home Office
# 28       Regular Air           3.90            Saskachewan         Consumer
# 29       Regular Air          13.56            Nova Scotia   Small Business
# ...              ...            ...                    ...              ...
# 8369     Regular Air           1.39                 Quebec        Corporate
# 8370     Regular Air          11.54                  Yukon      Home Office
# 8371     Regular Air           5.14               Manitoba      Home Office
# 8372  Delivery Truck          58.92  Northwest Territories        Corporate
# 8373     Regular Air           8.37                Ontario   Small Business
# 8374     Regular Air           1.29               Manitoba      Home Office
# 8375     Regular Air           2.00                Ontario      Home Office
# 8376     Regular Air          69.00                 Quebec        Corporate
# 8377     Regular Air           1.99                Ontario         Consumer
# 8378     Regular Air           4.51           Newfoundland        Corporate
# 8379     Express Air           6.60               Manitoba         Consumer
# 8380     Express Air           2.99            Nova Scotia         Consumer
# 8381     Regular Air           4.95                Ontario         Consumer
# 8382     Regular Air           4.50                  Yukon        Corporate
# 8383     Regular Air           2.87       British Columbia      Home Office
# 8384     Regular Air           8.99          New Brunswick        Corporate
# 8385     Regular Air           1.39  Northwest Territories        Corporate
# 8386     Regular Air           6.25                Ontario         Consumer
# 8387     Express Air           3.50                Alberta        Corporate
# 8388     Regular Air           7.46            Saskachewan      Home Office
# 8389     Regular Air          35.00  Northwest Territories      Home Office
# 8390     Regular Air           9.17                Alberta      Home Office
# 8391     Regular Air           5.92                  Yukon        Corporate
# 8392     Regular Air           0.70                 Quebec        Corporate
# 8393     Regular Air           5.59               Manitoba      Home Office
# 8394     Regular Air           0.99                Ontario        Corporate
# 8395     Regular Air          19.99       British Columbia         Consumer
# 8396     Regular Air           1.99                Alberta        Corporate
# 8397     Express Air           2.50                  Yukon      Home Office
# 8398     Regular Air           6.46       British Columbia        Corporate
#
#      Product Category            Product Sub-Category Product Container  \
# 0           Furniture              Office Furnishings         Small Box
# 1          Technology    Telephones and Communication        Medium Box
# 2     Office Supplies             Pens & Art Supplies          Wrap Bag
# 3           Furniture              Chairs & Chairmats        Jumbo Drum
# 4          Technology            Computer Peripherals         Small Box
# 5     Office Supplies                           Paper         Small Box
# 6          Technology            Computer Peripherals        Small Pack
# 7     Office Supplies  Binders and Binder Accessories         Small Box
# 8     Office Supplies   Scissors, Rulers and Trimmers          Wrap Bag
# 9          Technology                 Copiers and Fax         Large Box
# 10    Office Supplies  Binders and Binder Accessories         Small Box
# 11         Technology            Computer Peripherals         Small Box
# 12    Office Supplies             Pens & Art Supplies          Wrap Bag
# 13          Furniture                          Tables         Large Box
# 14    Office Supplies                           Paper          Wrap Bag
# 15    Office Supplies             Pens & Art Supplies          Wrap Bag
# 16    Office Supplies          Storage & Organization         Small Box
# 17         Technology                 Office Machines        Medium Box
# 18    Office Supplies                       Envelopes         Small Box
# 19    Office Supplies                          Labels         Small Box
# 20    Office Supplies                           Paper         Small Box
# 21         Technology    Telephones and Communication        Small Pack
# 22    Office Supplies                          Labels         Small Box
# 23         Technology    Telephones and Communication         Small Box
# 24    Office Supplies                           Paper         Small Box
# 25         Technology    Telephones and Communication         Small Box
# 26    Office Supplies                           Paper         Small Box
# 27    Office Supplies                           Paper          Wrap Bag
# 28         Technology    Telephones and Communication         Small Box
# 29          Furniture              Office Furnishings         Large Box
# ...               ...                             ...               ...
# 8369  Office Supplies                       Envelopes         Small Box
# 8370  Office Supplies                           Paper         Small Box
# 8371  Office Supplies  Binders and Binder Accessories         Small Box
# 8372        Furniture              Chairs & Chairmats        Jumbo Drum
# 8373  Office Supplies   Scissors, Rulers and Trimmers        Small Pack
# 8374  Office Supplies             Pens & Art Supplies          Wrap Bag
# 8375  Office Supplies                    Rubber Bands          Wrap Bag
# 8376        Furniture                          Tables         Large Box
# 8377       Technology            Computer Peripherals        Small Pack
# 8378  Office Supplies          Storage & Organization         Small Box
# 8379  Office Supplies                           Paper         Small Box
# 8380  Office Supplies  Binders and Binder Accessories         Small Box
# 8381        Furniture              Office Furnishings         Small Box
# 8382  Office Supplies                      Appliances         Small Box
# 8383  Office Supplies                           Paper          Wrap Bag
# 8384  Office Supplies             Pens & Art Supplies        Small Pack
# 8385  Office Supplies                       Envelopes         Small Box
# 8386  Office Supplies          Storage & Organization         Small Box
# 8387  Office Supplies                      Appliances         Small Box
# 8388  Office Supplies          Storage & Organization         Small Box
# 8389  Office Supplies          Storage & Organization         Large Box
# 8390  Office Supplies                           Paper         Small Box
# 8391       Technology    Telephones and Communication         Small Box
# 8392  Office Supplies             Pens & Art Supplies          Wrap Bag
# 8393  Office Supplies  Binders and Binder Accessories         Small Box
# 8394  Office Supplies                          Labels         Small Box
# 8395  Office Supplies  Binders and Binder Accessories         Small Box
# 8396       Technology            Computer Peripherals        Small Pack
# 8397       Technology    Telephones and Communication         Small Box
# 8398  Office Supplies  Binders and Binder Accessories         Small Box
#
#       Ship Date
# 0    2011-03-03
# 1    2010-07-25
# 2    2012-12-17
# 3    2011-01-04
# 4    2012-05-10
# 5    2011-06-09
# 6    2011-11-14
# 7    2010-10-20
# 8    2011-08-22
# 9    2009-02-27
# 10   2009-12-02
# 11   2010-12-24
# 12   2011-02-08
# 13   2009-08-25
# 14   2011-01-17
# 15   2011-03-19
# 16   2012-08-13
# 17   2011-06-08
# 18   2009-03-25
# 19   2009-03-24
# 20   2009-08-24
# 21   2012-05-13
# 22   2012-09-08
# 23   2010-02-05
# 24   2012-08-11
# 25   2011-06-27
# 26   2012-03-13
# 27   2009-08-20
# 28   2010-12-19
# 29   2009-09-27
# ...         ...
# 8369 2010-02-02
# 8370 2012-07-09
# 8371 2012-12-19
# 8372 2009-02-20
# 8373 2012-07-05
# 8374 2012-01-30
# 8375 2009-09-25
# 8376 2012-11-04
# 8377 2010-09-04
# 8378 2010-05-18
# 8379 2010-04-12
# 8380 2010-12-03
# 8381 2011-11-29
# 8382 2011-11-25
# 8383 2012-01-23
# 8384 2011-10-21
# 8385 2010-05-20
# 8386 2011-06-23
# 8387 2010-09-21
# 8388 2010-03-04
# 8389 2011-10-05
# 8390 2010-10-04
# 8391 2010-04-12
# 8392 2012-09-18
# 8393 2012-03-01
# 8394 2012-04-27
# 8395 2011-09-13
# 8396 2010-02-11
# 8397 2010-07-30
# 8398 2010-07-17
#
# [8399 rows x 13 columns]
